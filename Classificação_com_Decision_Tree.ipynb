# %% [markdown]
# <a href="https://colab.research.google.com/github/paulcesarbaruk/Analsying-the-Salary-of-Data-Scientists/blob/main/Classifica%C3%A7%C3%A3o_com_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://img.freepik.com/fotos-gratis/casal-gerenciando-orcamento-juntos-na-cozinha_273609-4844.jpg?w=1060&t=st=1703855492~exp=1703856092~hmac=8cc50c6ed00fe2b618aec034e43dcd4e1453948b2499bbfabdd7e018d622d592" alt="Alternative text" />

# %% [markdown]
# # **Classificação com Decision Tree**

# %% [markdown]
# ## **Objetivo**
#
# Nesta prática, vamos ver um problema de **Classificação** em Machine Learning. Se a Regressão é usada para a previsão de variáveis numéricas, a classificação é útil para variáveis categóricas.
#
# Aqui, a tarefa será determinar se após um telefonema de um banco de Portugual, o cliente fará um depósito na conta baseado em seu histórico pessoal, no histórico no banco e em tentativas de contato anteriores.

# %% [markdown]
# ## **Prática**

# %% [markdown]
# ### **Preparativos**
#
# Os dados que iremos analisar são do conjunto de dados [Bank marketing campaigns dataset | Opening Deposit](https://www.kaggle.com/datasets/volodymyrgavrysh/bank-marketing-campaigns-dataset?select=bank-additional-full.csv), disponível no Kaggle.

# %%
#Importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Montando o drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Lendo o arquivo CSV
dados = pd.read_csv('/content/drive/MyDrive/bank-additional-full.csv', sep=';')

# %% [markdown]
# O parâmetro `sep=';'`, usado acima, indica que queremos usar ponto e vírgula para separar os dados em colunas.

# %% [markdown]
# ### **Análise exploratória dos dados**
#
# Tendo importado os dados, vamos analisá-los para entendê-los melhor:

# %%
dados.head(5).style.background_gradient(axis=None, vmin=6.7, vmax=21.6)
# Out:
# <style type="text/css">
# #T_a8024_row0_col0, #T_a8024_row0_col10, #T_a8024_row0_col12, #T_a8024_row0_col16, #T_a8024_row0_col19, #T_a8024_row1_col0, #T_a8024_row1_col10, #T_a8024_row1_col12, #T_a8024_row1_col16, #T_a8024_row1_col19, #T_a8024_row2_col0, #T_a8024_row2_col10, #T_a8024_row2_col12, #T_a8024_row2_col16, #T_a8024_row2_col19, #T_a8024_row3_col0, #T_a8024_row3_col10, #T_a8024_row3_col12, #T_a8024_row3_col16, #T_a8024_row3_col19, #T_a8024_row4_col0, #T_a8024_row4_col10, #T_a8024_row4_col12, #T_a8024_row4_col16, #T_a8024_row4_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a8024_row0_col11, #T_a8024_row0_col13, #T_a8024_row0_col15, #T_a8024_row0_col17, #T_a8024_row0_col18, #T_a8024_row1_col11, #T_a8024_row1_col13, #T_a8024_row1_col15, #T_a8024_row1_col17, #T_a8024_row1_col18, #T_a8024_row2_col11, #T_a8024_row2_col13, #T_a8024_row2_col15, #T_a8024_row2_col17, #T_a8024_row2_col18, #T_a8024_row3_col11, #T_a8024_row3_col13, #T_a8024_row3_col15, #T_a8024_row3_col17, #T_a8024_row3_col18, #T_a8024_row4_col11, #T_a8024_row4_col13, #T_a8024_row4_col15, #T_a8024_row4_col17, #T_a8024_row4_col18 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_a8024" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8024_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_a8024_level0_col1" class="col_heading level0 col1" >job</th>
#       <th id="T_a8024_level0_col2" class="col_heading level0 col2" >marital</th>
#       <th id="T_a8024_level0_col3" class="col_heading level0 col3" >education</th>
#       <th id="T_a8024_level0_col4" class="col_heading level0 col4" >default</th>
#       <th id="T_a8024_level0_col5" class="col_heading level0 col5" >housing</th>
#       <th id="T_a8024_level0_col6" class="col_heading level0 col6" >loan</th>
#       <th id="T_a8024_level0_col7" class="col_heading level0 col7" >contact</th>
#       <th id="T_a8024_level0_col8" class="col_heading level0 col8" >month</th>
#       <th id="T_a8024_level0_col9" class="col_heading level0 col9" >day_of_week</th>
#       <th id="T_a8024_level0_col10" class="col_heading level0 col10" >duration</th>
#       <th id="T_a8024_level0_col11" class="col_heading level0 col11" >campaign</th>
#       <th id="T_a8024_level0_col12" class="col_heading level0 col12" >pdays</th>
#       <th id="T_a8024_level0_col13" class="col_heading level0 col13" >previous</th>
#       <th id="T_a8024_level0_col14" class="col_heading level0 col14" >poutcome</th>
#       <th id="T_a8024_level0_col15" class="col_heading level0 col15" >emp.var.rate</th>
#       <th id="T_a8024_level0_col16" class="col_heading level0 col16" >cons.price.idx</th>
#       <th id="T_a8024_level0_col17" class="col_heading level0 col17" >cons.conf.idx</th>
#       <th id="T_a8024_level0_col18" class="col_heading level0 col18" >euribor3m</th>
#       <th id="T_a8024_level0_col19" class="col_heading level0 col19" >nr.employed</th>
#       <th id="T_a8024_level0_col20" class="col_heading level0 col20" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8024_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8024_row0_col0" class="data row0 col0" >56</td>
#       <td id="T_a8024_row0_col1" class="data row0 col1" >housemaid</td>
#       <td id="T_a8024_row0_col2" class="data row0 col2" >married</td>
#       <td id="T_a8024_row0_col3" class="data row0 col3" >basic.4y</td>
#       <td id="T_a8024_row0_col4" class="data row0 col4" >no</td>
#       <td id="T_a8024_row0_col5" class="data row0 col5" >no</td>
#       <td id="T_a8024_row0_col6" class="data row0 col6" >no</td>
#       <td id="T_a8024_row0_col7" class="data row0 col7" >telephone</td>
#       <td id="T_a8024_row0_col8" class="data row0 col8" >may</td>
#       <td id="T_a8024_row0_col9" class="data row0 col9" >mon</td>
#       <td id="T_a8024_row0_col10" class="data row0 col10" >261</td>
#       <td id="T_a8024_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_a8024_row0_col12" class="data row0 col12" >999</td>
#       <td id="T_a8024_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_a8024_row0_col14" class="data row0 col14" >nonexistent</td>
#       <td id="T_a8024_row0_col15" class="data row0 col15" >1.100000</td>
#       <td id="T_a8024_row0_col16" class="data row0 col16" >93.994000</td>
#       <td id="T_a8024_row0_col17" class="data row0 col17" >-36.400000</td>
#       <td id="T_a8024_row0_col18" class="data row0 col18" >4.857000</td>
#       <td id="T_a8024_row0_col19" class="data row0 col19" >5191.000000</td>
#       <td id="T_a8024_row0_col20" class="data row0 col20" >no</td>
#     </tr>
#     <tr>
#       <th id="T_a8024_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8024_row1_col0" class="data row1 col0" >57</td>
#       <td id="T_a8024_row1_col1" class="data row1 col1" >services</td>
#       <td id="T_a8024_row1_col2" class="data row1 col2" >married</td>
#       <td id="T_a8024_row1_col3" class="data row1 col3" >high.school</td>
#       <td id="T_a8024_row1_col4" class="data row1 col4" >unknown</td>
#       <td id="T_a8024_row1_col5" class="data row1 col5" >no</td>
#       <td id="T_a8024_row1_col6" class="data row1 col6" >no</td>
#       <td id="T_a8024_row1_col7" class="data row1 col7" >telephone</td>
#       <td id="T_a8024_row1_col8" class="data row1 col8" >may</td>
#       <td id="T_a8024_row1_col9" class="data row1 col9" >mon</td>
#       <td id="T_a8024_row1_col10" class="data row1 col10" >149</td>
#       <td id="T_a8024_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_a8024_row1_col12" class="data row1 col12" >999</td>
#       <td id="T_a8024_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_a8024_row1_col14" class="data row1 col14" >nonexistent</td>
#       <td id="T_a8024_row1_col15" class="data row1 col15" >1.100000</td>
#       <td id="T_a8024_row1_col16" class="data row1 col16" >93.994000</td>
#       <td id="T_a8024_row1_col17" class="data row1 col17" >-36.400000</td>
#       <td id="T_a8024_row1_col18" class="data row1 col18" >4.857000</td>
#       <td id="T_a8024_row1_col19" class="data row1 col19" >5191.000000</td>
#       <td id="T_a8024_row1_col20" class="data row1 col20" >no</td>
#     </tr>
#     <tr>
#       <th id="T_a8024_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8024_row2_col0" class="data row2 col0" >37</td>
#       <td id="T_a8024_row2_col1" class="data row2 col1" >services</td>
#       <td id="T_a8024_row2_col2" class="data row2 col2" >married</td>
#       <td id="T_a8024_row2_col3" class="data row2 col3" >high.school</td>
#       <td id="T_a8024_row2_col4" class="data row2 col4" >no</td>
#       <td id="T_a8024_row2_col5" class="data row2 col5" >yes</td>
#       <td id="T_a8024_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_a8024_row2_col7" class="data row2 col7" >telephone</td>
#       <td id="T_a8024_row2_col8" class="data row2 col8" >may</td>
#       <td id="T_a8024_row2_col9" class="data row2 col9" >mon</td>
#       <td id="T_a8024_row2_col10" class="data row2 col10" >226</td>
#       <td id="T_a8024_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_a8024_row2_col12" class="data row2 col12" >999</td>
#       <td id="T_a8024_row2_col13" class="data row2 col13" >0</td>
#       <td id="T_a8024_row2_col14" class="data row2 col14" >nonexistent</td>
#       <td id="T_a8024_row2_col15" class="data row2 col15" >1.100000</td>
#       <td id="T_a8024_row2_col16" class="data row2 col16" >93.994000</td>
#       <td id="T_a8024_row2_col17" class="data row2 col17" >-36.400000</td>
#       <td id="T_a8024_row2_col18" class="data row2 col18" >4.857000</td>
#       <td id="T_a8024_row2_col19" class="data row2 col19" >5191.000000</td>
#       <td id="T_a8024_row2_col20" class="data row2 col20" >no</td>
#     </tr>
#     <tr>
#       <th id="T_a8024_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8024_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_a8024_row3_col1" class="data row3 col1" >admin.</td>
#       <td id="T_a8024_row3_col2" class="data row3 col2" >married</

# %% [markdown]
# As variáveis ou *features* do dataset são:
#
# * **age:** idade (variável numérica);
# * **job:** emprego (variável categórica);
# * **marital:** estado civíl (variável categórica);
# * **education:** nível de educação (variável categórica);
# * **default:** já tem crédito? (variável categórica);
# * **housing:** tem hipoteca? (variável categórica);
# * **loan::** empréstimo pessoal? (variável categórica);
# * **contact:** tipo de contato (variável categórica);
# * **month:** mês do último contato (variável categórica);
# * **day_of_week:** dia da semana da tentativa de contato (variável categórica);
# * **duration:** duração da última chamada (variável numérica);
# * **campaign:** número de ligações para o cliente (variável numérica);
# * **pdays:** intervalo entre as duas últimas ligações (variável numérica);
# * **previous:** número de ligações antes desta campanha (variável numérica);
# * **poutcome:** resultado da última campanha (variável categórica);
# * **emp.var.rate:** taxa da variaçào de emprego (variável numérica);
# * **cons.price.idx:** indice de preço do consumidor (variável numérica);
# * **cons.conf.idx:** indice de confiança do consumidor (variável numérica);
# * **euribor3m** indicador diário (variável numérica);
# * **nr.employed:** número de funcionários (variável numérica);
# * **y:** resultado (variável categórica).

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# Qual é a faixa etária dos clientes do Banco?

# %%
dados['age'].plot(kind='hist')
plt.xlabel('Idade')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %% [markdown]
# Observa-se que maioria dos clientes estão na faixa entre 30 e 50 anos.

# %%
sns.countplot(x='marital',data=dados,hue='y')
# Out:
# <Axes: xlabel='marital', ylabel='count'>

# %% [markdown]
# Os clientes mais procurados são casados. Normalmente, são pessoas mais organizadas financeiramente e possuem renda somada (do marido e da esposa).

# %%
plt.figure(figsize = (12,5))
sns.countplot(x='education',data=dados,hue='y')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %% [markdown]
# Clientes mais procurados têm ensino médio completo ou superior completo. Isto está relacionado com terem maior renda e maior possibilidade de pagarem as contas em dia.

# %%
sns.countplot(x='default',data=dados)
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %% [markdown]
# Clientes que não têm empréstimo no momento devem ser mais procurados por estarem em melhor condição financeira.

# %%
sns.countplot(x='housing',data=dados,hue='y')
# Out:
# <Axes: xlabel='housing', ylabel='count'>

# %%
sns.countplot(x='loan',data=dados,hue='y')
# Out:
# <Axes: xlabel='loan', ylabel='count'>

# %%
sns.countplot(x='contact',data=dados,hue='y')
# Out:
# <Axes: xlabel='contact', ylabel='count'>

# %%
sns.countplot(x='month',data=dados)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %% [markdown]
# Quais dias da semana foram feitas mais ligações?

# %%
sns.countplot(x='day_of_week',data=dados)
# Out:
# <Axes: xlabel='day_of_week', ylabel='count'>

# %% [markdown]
# Os dias que foram feitas mais ligações foram segunda e quinta-feira.

# %%
dados['duration'].plot(kind='hist')
plt.xlabel('Duração')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['campaign'].plot(kind='hist')
plt.xlabel('Número de ligações')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['pdays'].plot(kind='hist')
plt.xlabel('Número de dias')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['previous'].plot(kind='hist')
plt.xlabel('Número de ligações anteriores')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
sns.countplot(x='poutcome',data=dados)
# Out:
# <Axes: xlabel='poutcome', ylabel='count'>

# %%
dados['emp.var.rate'].plot(kind='hist')
plt.xlabel('Taxa de variação de emprego')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['cons.price.idx'].plot(kind='hist')
plt.xlabel('Indice de preço')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['cons.conf.idx'].plot(kind='hist')
plt.xlabel('Indice de confiança')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['euribor3m'].plot(kind='hist')
plt.xlabel('Indicador diario')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
dados['nr.employed'].plot(kind='hist')
plt.xlabel('Número de funcionários')
plt.ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %%
sns.countplot(x='y',data=dados)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %% [markdown]
# ### **Feature selection**
#
# A partir daqui, faremos a seleção de variáveis para nosso modelo de classificação.
#
# Observamos que a amostra não está balanceada. Isso poderá fazer com que o modelo falhe para os casos que aceitaram a proposta.
#
# Caso isso se confirme, iremos utilizar uma amostra aleatória de clientes que recusaram com o mesmo tamanho do número de clientes que aceitaram a proposta.
#
# Como o número de ligações durante a semana está balanceado, podemos remover esta informação:

# %%
dados = dados.drop('day_of_week',axis=1)

# %% [markdown]
# Convertendo variáveis catgóricas em variáveis numéricas usando dicionário Python:

# %%
dados['y'] = dados['y'].map({'yes' : 1, 'no' : 0})

# %%
dados.head()

# %% [markdown]
# Convertendo utilizando [LabelEnconder](https://www.viniboscoa.dev/blog/codificacao-de-variaveis-label-vs-one-hot-encoder):

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enconder = LabelEncoder()

# %%
dados['job'] = enconder.fit_transform(dados['job'])
dados['marital'] = enconder.fit_transform(dados['marital'])
dados['education'] = enconder.fit_transform(dados['education'])
dados['default'] = enconder.fit_transform(dados['default'])
dados['housing'] = enconder.fit_transform(dados['housing'])
dados['loan'] = enconder.fit_transform(dados['loan'])
dados['contact'] = enconder.fit_transform(dados['contact'])
dados['month'] = enconder.fit_transform(dados['month'])
dados['poutcome'] = enconder.fit_transform(dados['poutcome'])

# %%
dados.head()

# %% [markdown]
# Em algumas colunas numéricas, os dados apresentam uma variação muito grande. Isto pode afetar a eficiência do modelo. Por esta razão, eles serão normalizados:

# %%
colunas = ['age','duration','pdays','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']

# %%
print(dados['cons.price.idx'].min())
print(dados['cons.price.idx'].max())

# %%
print(dados['cons.conf.idx'].min())
print(dados['cons.conf.idx'].max())

# %%
print(dados['euribor3m'].min())
print(dados['euribor3m'].max())

# %%
print(dados['nr.employed'].min())
print(dados['nr.employed'].max())

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
dados[colunas] = sc.fit_transform(dados[colunas])

# %%
dados.head()

# %% [markdown]
# Verificando a correlação dos dados:

# %%
correlacao = dados.corr()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(correlacao)
plt.title('Mapa de calor dos coeficientes de correlação')

# %% [markdown]
# Separando as variaveis em X e Y:

# %%
X = dados.drop('y',axis=1).values
Y = dados['y'].values

# %% [markdown]
# ### **Criando o modelo**
#
# Separando em amostras de *treino* e *teste*, uma prática comum em Machine Learning:

# %%
from sklearn.model_selection import train_test_split

# %%
X_treino,X_teste,Y_treino,Y_teste=train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# Aplicando o modelo da arvore de decisão:

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dte = DecisionTreeClassifier()

# %%
dte.get_params

# %% [markdown]
# Realizando ajuste do modelo:

# %%
dte.fit(X_treino,Y_treino)

# %% [markdown]
# ### **Avaliando o modelo**

# %% [markdown]
# #### **Acurácia da amostra de treino**

# %%
score_treino = dte.score(X_treino,Y_treino)

# %%
score_treino

# %% [markdown]
# #### **Previsão da amostra de teste**

# %%
Y_previsto = dte.predict(X_teste)

# %%
score_teste = dte.score(X_teste,Y_teste)

# %%
score_teste

# %% [markdown]
# #### **Matriz de confusão**

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(Y_teste,Y_previsto)

# %%
cm

# %%
sns.heatmap(cm,annot=True, fmt="d")

# %%
from sklearn.metrics import classification_report,f1_score,precision_score,average_precision_score,recall_score,accuracy_score

# %% [markdown]
# #### **Relatório de classificação**

# %%
cr = classification_report(Y_teste,Y_previsto,labels=[0,1])
print(cr)

# %% [markdown]
# ##### **Métricas**

# %% [markdown]
# ###### **F1-score**

# %%
f1 = f1_score(Y_teste,Y_previsto)
print("F1 score = {:0.2f}%".format(f1*100))

# %% [markdown]
# ###### **Precision score**

# %%
precisao = precision_score(Y_teste,Y_previsto)
print("Precision score = {:0.2f}%".format(precisao*100))

# %% [markdown]
# ###### **Average precision score**

# %%
avg_precision = average_precision_score(Y_teste,Y_previsto)
print("Averaged precision score = {:0.2f}%".format(avg_precision*100))

# %% [markdown]
# ###### **Recall score**

# %%
rec = recall_score(Y_teste,Y_previsto)
print("Recall score = {:0.2f}%".format(rec*100))

# %% [markdown]
# ###### **Accuracy score**

# %%
acc = accuracy_score(Y_teste,Y_previsto)
print("Accuracy score = {:0.2f}%".format(acc*100))

# %% [markdown]
# ##### **Curva ROC**

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_score = roc_auc_score(Y_teste, Y_previsto)
print("ROC score = {:0.2f}%".format(roc_score*100))

# %%
roc_fpr, roc_tpr, _ = roc_curve(Y_teste, Y_previsto)

# %%
plt.plot(roc_fpr, roc_tpr, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# %% [markdown]
# ##### **Curva Precision-Recall**

# %%
from sklearn.metrics import precision_recall_curve,auc

# %%
lr_precision, lr_recall, _ = precision_recall_curve(Y_teste, Y_previsto)
lr_auc = auc(lr_recall, lr_precision)

# %%
print("AUC score = {:0.2f}%".format(lr_auc*100))

# %%
plt.plot(lr_recall, lr_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')

# %% [markdown]
# #### **Gerando imagem da árvore**

# %%
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dte, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True, feature_names = dados.columns.drop('y'),class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('banco.png')
Image(graph.create_png(), width = 600, height = 300)

# %% [markdown]
# ---
#
# Notebook utilizado para fins educacionais da **Awari**.
#
# **© AWARI. Todos os direitos reservados.**
